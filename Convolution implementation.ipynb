# %% [markdown]
# # Convolution Implementation
#
# By Keegan Rhodes, 02-28-2022
#
# The purpose of this notebook is to implement convolution which will be enhanced with fourier in order to increase the performance of our implementation. In order to achieve this goal effectively, we will be using libraries such as numpy in order to increase the performance of the python code due to the usage of numpy arrays instead of python lists. Additionally, we will also be using matplotlib in order to visualize our changes to the image being processed.
#
# In this notebook, the images being used are obtained from the scikit learn sample images dataset. More information about this dataset can be found here: https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_sample_image.html
#
# Documentation for numpy can be found here: https://numpy.org/doc/
#
# Documentation for matplotlib can be found here: https://matplotlib.org/

# %% [markdown]
# First we start off with some general import statements in order to load everything that will be required later on.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_sample_images

# %% [markdown]
# Next, we load in the first image in order to view it before performing any sort of convolution operations.

# %%
data = load_sample_images()
image = data.images[0]
plt.imshow(image)
plt.xticks([]);
plt.yticks([]);
plt.title("First image in the dataset");
